# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait as wait
from selenium.webdriver.common.keys import Keys
import time

# %%
browser = webdriver.Chrome('/Users/Sigrid/Downloads/chromedriver')
browser.get('https://leadsdeposit.com/list-of-all-kfc-locations-in-the-us/')
browser.maximize_window() # For maximizing window

address_list = []
city_list = []
state_list = []
zip_code_list = []
lat_list = []
lon_list = []

# %%
for i in range(200):
    try:
        button = browser.find_element_by_css_selector('#footable_10800 > tfoot > tr > td > div > ul > li:nth-child(802) > a')
        button.send_keys("\n")
        time.sleep(1)
        address = browser.find_elements_by_xpath('//*[@class="ninja_column_1 ninja_clmn_nm_address"]')
        time.sleep(1)
        city = browser.find_elements_by_xpath('//*[@class="ninja_column_2 ninja_clmn_nm_city"]')
        time.sleep(1)
        state = browser.find_elements_by_xpath('//*[@class="ninja_column_3 ninja_clmn_nm_state"]')
        time.sleep(1)
        zip_code = browser.find_elements_by_xpath('//*[@class="ninja_column_4 ninja_clmn_nm_zipcode"]')
        time.sleep(1)
        lat = browser.find_elements_by_xpath('//*[@class="ninja_column_6 ninja_clmn_nm_latitude"]')
        time.sleep(1)
        lon = browser.find_elements_by_xpath('//*[@class="ninja_column_7 ninja_clmn_nm_longitude"]')
        for add in address:
            address_list.append(add.text)
            print(add.text)
        for c in city:
            city_list.append(c.text)
            print(c.text)
        for s in state:
            state_list.append(s.text)
            print(s.text)
        for z in zip_code:
            zip_code_list.append(z.text)
            print(z.text)
        for la in lat:
            lat_list.append(la.text)
            print(la.text)
        for lo in lon:
            lon_list.append(lo.text)
            print(lo.text)
    except (exceptions.StaleElementReferenceException, exceptions.ElementNotInteractableException) as e:  
        pass
# Out:
# 8510 Fredericksburg Rd
# 8727 Perrin Beitel
# 9160 Grissom Road
# 1120 S. Business 77
# 660 E. Hopkins Street
# San Antonio
# San Antonio
# San Antonio
# San Benito
# San Marcos
# TX
# TX
# TX
# TX
# TX
# 78229
# 78217
# 78251
# 78586
# 78666
# 29.51928391
# 29.51930338
# 29.48399882
# 26.14532868
# 29.88472932
# -98.57287992
# -98.41105347
# -98.66559079
# -97.63592311
# -97.92440933
# 17397 IH 35 North
# 4214 N. Highway 75
# 815 Highway 96, S
# 3201 Padre Boulevard
# 101 North Kimball Avenue
# Schertz
# Sherman
# Silsbee
# South Padre Island
# Southlake
# TX
# TX
# TX
# TX
# TX
# 78154
# 75090
# 77656
# 78597
# 76092
# 29.59883977
# 33.68376837
# 30.34206362
# 26.10775948
# 32.94129255
# -98.27973434
# -96.60787552
# -94.18203068
# -97.16876149
# -97.1161167
# 14709 US Highway 59
# 2058 FM 2920
# 12570 Southwest Freeway
# 3501 Highway 6
# 4950 Highway 90A
# Splendora
# Spring
# Stafford
# Sugar Land
# Sugar Land
# TX
# TX
# TX
# TX
# TX
# 77372
# 77388
# 77477
# 77478
# 77498
# ...

# %%
KFC = pd.DataFrame(list(zip(address_list, city_list,state_list,zip_code_list,lat_list,lon_list)),
                  columns =['Address','City','State','Zip_code','LAT','LON'])

KFC = KFC.drop_duplicates()
KFC['State'].unique()
# Out:
# array(['AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA',
#        'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME',
#        'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM',
#        'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
#        'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY'], dtype=object)

# %%
KFC.to_csv('KFC_location.csv',index=False)

# %%
driver = webdriver.Chrome('/Users/Sigrid/Downloads/chromedriver')
driver.get('https://www.arcgis.com/home/item.html?id=cdfd8f55dc3f4b349b05b0abd148961d&view=list&sortOrder=desc&sortField=defaultFSOrder&showFilters=true#data')
driver.maximize_window() # For maximizing window
driver.implicitly_wait(20)

# %%
street     = driver.find_elements_by_xpath('//*[@class="dgrid-cell dgrid-cell-padding dgrid-column-2 field-STREET"]')
city       = driver.find_elements_by_xpath('//*[@class="dgrid-cell dgrid-cell-padding dgrid-column-3 field-CITY"]')
state      = driver.find_elements_by_xpath('//*[@class="dgrid-cell dgrid-cell-padding dgrid-column-4 field-STATE"]')
state_name = driver.find_elements_by_xpath('//*[@class="dgrid-cell dgrid-cell-padding dgrid-column-5 field-STATE_NAME"]')
zip_code   = driver.find_elements_by_xpath('//*[@class="dgrid-cell dgrid-cell-padding dgrid-column-6 field-ZIP"]')
LON        = driver.find_elements_by_xpath('//*[@class="dgrid-cell dgrid-cell-padding dgrid-column-20 field-LON"]')
LAT        = driver.find_elements_by_xpath('//*[@class="dgrid-cell dgrid-cell-padding dgrid-column-21 field-LAT"]')

# %%
import pandas as pd

street_list = []
city_list = []
state_list = []
state_name_list = []
zip_code_list = []
LON_list = []
LAT_list = []

for i in street:
    street_list.append(str(i.text))
for i in city:
    city_list.append(str(i.text))
for i in state:
    state_list.append(str(i.text))
for i in state_name:
    state_name_list.append(str(i.text))
for i in zip_code:
    zip_code_list.append(str(i.text))
for i in LON:
    LON_list.append(str(i.text))
for i in LAT:
    LAT_list.append(str(i.text))


df = pd.DataFrame(list(zip(street_list, city_list,state_list,state_name_list,zip_code_list,LON_list,LAT_list)),
                  columns =['Street','City','State','State_name','Zip_code','LAT','LON'])
df
# Out:
#               Street             City State  State_name Zip_code  \
# 0          SENTER RD         SAN JOSE    CA  California    95111
# 1         S WHITE RD         SAN JOSE    CA  California    95148
# 2           STORY RD         SAN JOSE    CA  California    95127
# 3       E COTATI AVE     ROHNERT PARK    CA  California    94928
# 4     EL CAMINO REAL  S SAN FRANCISCO    CA  California    94080
# ..               ...              ...   ...         ...      ...
# 105    NE HIGHWAY 99        VANCOUVER    WA  Washington    98665
# 106         15TH AVE         LONGVIEW    WA  Washington    98632
# 107      MOLALLA AVE      OREGON CITY    OR      Oregon    97045
# 108  MCLOUGHLIN BLVD        GLADSTONE    OR      Oregon    97027
# 109      SE 82ND AVE     HAPPY VALLEY    OR      Oregon    97086
#
#                      LAT                 LON
# 0    -121.83350000033874  37.292500000259736
# 1    -121.79300000013325  37.316199999844116
# 2    -121.81930000006258  37.355999999969185
# ...

# %%
street_1     = driver.find_elements_by_xpath('//*[@class="dgrid-cell dgrid-cell-padding dgrid-column-2 field-STREET"]')
# driver.execute_script("arguments[0].scrollIntoView();", street_1)
for i in range(100):
    driver.execute_script("arguments[0].scrollIntoView();", street[i])
# Out:
# ---------------------------------------------------------------------------
# StaleElementReferenceException            Traceback (most recent call last)
# <ipython-input-136-1c287fde306d> in <module>
#       2 # driver.execute_script("arguments[0].scrollIntoView();", street_1)
#       3 for i in range(100):
# ----> 4     driver.execute_script("arguments[0].scrollIntoView();", street[i])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute_script(self, script, *args)
#     634         return self.execute(command, {
#     635             'script': script,
# --> 636             'args': converted_args})['value']
#     637
#     638     def execute_async_script(self, script, *args):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# ...

# %%
len(street)
# Out:
# 110

# %%
# from selenium import webdriver
from bs4 import BeautifulSoup

driver = webdriver.Chrome('/Users/Sigrid/Downloads/chromedriver')
driver.get('https://leadsdeposit.com/list-of-all-kfc-locations-in-the-us/')

soup = BeautifulSoup(driver.page_source, 'html.parser')
reviews = []
review = soup.select('#footable_10800 tbody tr.ninja_table_row_5.nt_row_id_3989 td.ninja_column_1.ninja_clmn_nm_address')
for i in review:
    print(i.get_text(strip=True))
# review = review.strip()
# reviews.append(review)                                                   
# reviews                            

# /table/tbody/tr[1]/td[2]
# /table/tbody/tr[1]/td[2]
# <td class="ninja_column_1 ninja_clmn_nm_address" style="display: table-cell;">1761 Palmer Wasilla Highway</td>

# %%
review[0].get_text()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-179-30b5b0e40cd5> in <module>
# ----> 1 review[0].get_text()
#
# IndexError: list index out of range
